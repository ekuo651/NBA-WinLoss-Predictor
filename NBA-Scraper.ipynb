# %% [markdown]
# # **NBA Data Scraper**

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Tests for DF transformation

# %%
list_a = [['a',1],['b',2],['c',3]]

list_b = [['a',4],['b',5],['c',6]]

print( list_a + list_b)

# %%
dfa = pd.DataFrame(list_a).T
dfb = pd.DataFrame(list_b).T

# %%
list_of_df = [dfa,dfb]

# %%
pd.concat([i for i in list_of_df], axis='rows', join = 'inner')
# Out:
#    0  1  2
# 0  a  b  c
# 1  1  2  3
# 0  a  b  c
# 1  4  5  6

# %%
# retreive player box score for 1 season and return as dataframe -- DONE

# remove rows where player did not play for more than 5 minutes -- WORK IN PROGRESS
# remove rows where there are nulls due to injury or other

# encode game winner
# set and verify datatypes

def box_score(player_id, year):
    df = pd.DataFrame(client.regular_season_player_box_scores(player_identifier="westbru01", season_end_year=2019))
    df.dropna(axis=)

    return df

# %%
# retrieve box score for x years and return as dataframe -- DONE

def player_box_scores(player_id,year_start,year_stop):
    df = pd.concat([box_score(player_id, year) for year in range(year_start,year_stop)],
                   axis = 'rows',
                   join = 'inner')
    return df

# %% [markdown]
# ## Working with Sample Files

# %%
westbrook_path = 'Sample_Files/westbrook_2014_2019.csv'
westbrook_df = pd.read_csv(westbrook_path)
westbrook_df.head(10)
# Out:
#    Unnamed: 0        date                        team       location  \
# 0           0  2014-10-29  Team.OKLAHOMA_CITY_THUNDER  Location.AWAY
# 1           1  2014-10-30  Team.OKLAHOMA_CITY_THUNDER  Location.AWAY
# 2           2  2014-11-28  Team.OKLAHOMA_CITY_THUNDER  Location.HOME
# 3           3  2014-12-02  Team.OKLAHOMA_CITY_THUNDER  Location.AWAY
# 4           4  2014-12-05  Team.OKLAHOMA_CITY_THUNDER  Location.AWAY
# 5           5  2014-12-07  Team.OKLAHOMA_CITY_THUNDER  Location.AWAY
# 6           6  2014-12-09  Team.OKLAHOMA_CITY_THUNDER  Location.HOME
# 7           7  2014-12-11  Team.OKLAHOMA_CITY_THUNDER  Location.HOME
# 8           8  2014-12-12  Team.OKLAHOMA_CITY_THUNDER  Location.AWAY
# 9           9  2014-12-14  Team.OKLAHOMA_CITY_THUNDER  Location.HOME
#
#                       opponent       outcome  seconds_played  \
# 0  Team.PORTLAND_TRAIL_BLAZERS  Outcome.LOSS            1959
# 1    Team.LOS_ANGELES_CLIPPERS  Outcome.LOSS             523
# ...

# %%
westbrook_df.sample(10)
# Out:
#      Unnamed: 0        date                        team       location  \
# 164          17  2016-11-26  Team.OKLAHOMA_CITY_THUNDER  Location.HOME
# 190          43  2017-01-18  Team.OKLAHOMA_CITY_THUNDER  Location.AWAY
# 219          72  2017-03-27  Team.OKLAHOMA_CITY_THUNDER  Location.AWAY
# 58           58  2015-03-29  Team.OKLAHOMA_CITY_THUNDER  Location.AWAY
# 50           50  2015-03-15  Team.OKLAHOMA_CITY_THUNDER  Location.HOME
# 207          60  2017-03-02  Team.OKLAHOMA_CITY_THUNDER  Location.AWAY
# 8             8  2014-12-12  Team.OKLAHOMA_CITY_THUNDER  Location.AWAY
# 116          49  2016-02-01  Team.OKLAHOMA_CITY_THUNDER  Location.HOME
# 71            4  2015-11-04  Team.OKLAHOMA_CITY_THUNDER  Location.HOME
# 363          55  2019-03-05  Team.OKLAHOMA_CITY_THUNDER  Location.AWAY
#
#                         opponent       outcome  seconds_played  \
# 164         Team.DETROIT_PISTONS   Outcome.WIN            2239
# ...

# %%
westbrook_df.dtypes
# Out:
# Unnamed: 0                             int64
# date                                  object
# team                                  object
# location                              object
# opponent                              object
# outcome                               object
# seconds_played                         int64
# made_field_goals                       int64
# attempted_field_goals                  int64
# made_three_point_field_goals           int64
# attempted_three_point_field_goals      int64
# made_free_throws                       int64
# attempted_free_throws                  int64
# offensive_rebounds                     int64
# defensive_rebounds                     int64
# assists                                int64
# steals                                 int64
# blocks                                 int64
# turnovers                              int64
# personal_fouls                         int64
# points_scored                          int64
# ...

# %% [markdown]
# ## Get list of player_id's & player_names

# %%
advanced_stats_2019_path = 'Sample_Files/advanced_season_totals_2019.csv'
advanced_2019 = pd.read_csv(advanced_stats_2019_path)
advanced_2019.head()
# Out:
#    Unnamed: 0       slug          name  \
# 0           0  abrinal01  Álex Abrines
# 1           1    acyqu01    Quincy Acy
# 2           2  adamsja01  Jaylen Adams
# 3           3  adamsst01  Steven Adams
# 4           4  adebaba01   Bam Adebayo
#
#                                        positions  age  \
# 0  [<Position.SHOOTING_GUARD: 'SHOOTING GUARD'>]   25
# 1    [<Position.POWER_FORWARD: 'POWER FORWARD'>]   28
# 2        [<Position.POINT_GUARD: 'POINT GUARD'>]   22
# 3                  [<Position.CENTER: 'CENTER'>]   25
# 4                  [<Position.CENTER: 'CENTER'>]   21
#
#                          team  games_played  minutes_played  \
# 0  Team.OKLAHOMA_CITY_THUNDER            31             588
# 1           Team.PHOENIX_SUNS            10             123
# 2          Team.ATLANTA_HAWKS            34             428
# 3  Team.OKLAHOMA_CITY_THUNDER            80            2669
# 4             Team.MIAMI_HEAT            82            1913
#
# ...

# %%
player_ids = advanced_2019['slug'].to_list()
print(len(player_ids))
print(player_ids[:5])
# Out:
# 622
# ['abrinal01', 'acyqu01', 'adamsja01', 'adamsst01', 'adebaba01']

# %%
player_names = advanced_2019['name'].to_list()
print(len(player_names))
print(player_names[:5])
# Out:
# 622
# ['Álex Abrines', 'Quincy Acy', 'Jaylen Adams', 'Steven Adams', 'Bam Adebayo']

# %%
## Function to get all players box scores for x years - Work In Progress

## Export each player's file to csv
def export_csv(i):
    
    name = str(player_names[i]).replace(' ','')
    filename = 'PlayerBoxScores/'+name+'.csv'   
    df.to_csv(filename)
