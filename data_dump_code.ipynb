# %%
# pip install basketball-reference-web-scraper

# %%
from basketball_reference_web_scraper import client
from basketball_reference_web_scraper.data import Team
import pandas as pd
import numpy as np

# %% [markdown]
# ## **Season Totals Raw** - Very Useful

# %%
raw_totals_2018 = client.players_season_totals(2018)

# %%
# raw_totals_2018

# %%
df_raw_totals_2018 = pd.DataFrame(raw_totals_2018)
df_raw_totals_2018.head(10)
# Out:
#         slug               name                  positions  age  \
# 0  abrinal01       Álex Abrines  [Position.SHOOTING_GUARD]   24
# 1    acyqu01         Quincy Acy   [Position.POWER_FORWARD]   27
# 2  adamsst01       Steven Adams          [Position.CENTER]   24
# 3  adebaba01        Bam Adebayo          [Position.CENTER]   20
# 4  afflaar01      Arron Afflalo  [Position.SHOOTING_GUARD]   32
# 5  aldrico01       Cole Aldrich          [Position.CENTER]   29
# 6  aldrila01  LaMarcus Aldridge          [Position.CENTER]   32
# 7  allenja01      Jarrett Allen          [Position.CENTER]   19
# 8  allenka01       Kadeem Allen     [Position.POINT_GUARD]   25
# 9  allento01         Tony Allen   [Position.SMALL_FORWARD]   36
#
#                           team  games_played  games_started  minutes_played  \
# 0   Team.OKLAHOMA_CITY_THUNDER            75              8            1134
# 1           Team.BROOKLYN_NETS            70              8            1359
# 2   Team.OKLAHOMA_CITY_THUNDER            76             76            2487
# 3              Team.MIAMI_HEAT            69             19            1368
# 4           Team.ORLANDO_MAGIC            53              3             682
# 5  Team.MINNESOTA_TIMBERWOLVES            21              0              49
# 6       Team.SAN_ANTONIO_SPURS            75             75            2509
# 7           Team.BROOKLYN_NETS            72             31            1441
# 8          Team.BOSTON_CELTICS            18              1             107
# 9    Team.NEW_ORLEANS_PELICANS            22              0             273
#
#    made_field_goals  attempted_field_goals  ...  made_free_throws  \
# 0               115                    291  ...                39
# 1               130                    365  ...                49
# 2               448                    712  ...               160
# 3               174                    340  ...               129
# 4                65                    162  ...                22
# 5                 5                     15  ...                 2
# 6               687                   1347  ...               334
# 7               234                    397  ...               114
# 8                 6                     22  ...                 7
# 9                44                     91  ...                11
#
#    attempted_free_throws  offensive_rebounds  defensive_rebounds  assists  \
# 0                     46                  26                  88       28
# 1                     60                  40                 217       57
# 2                    286                 384                 301       88
# 3                    179                 118                 263      101
# 4                     26                   4                  62       30
# 5                      6                   3                  12        3
# 6                    399                 246                 389      152
# 7                    147                 144                 244       49
# 8                      9                   4                   7       12
# 9                     21                  20                  27        9
#
#    steals  blocks  turnovers  personal_fouls  points
# 0      38       8         25             124     353
# 1      33      29         60             149     411
# 2      92      78        128             215    1056
# 3      32      41         66             138     477
# 4       4       9         21              56     179
# 5       2       1          1              11      12
# 6      43      90        111             161    1735
# 7      28      88         82             147     587
# 8       3       2          9              15      19
# 9      11       3         19              49     103
#
# [10 rows x 22 columns]

# %% [markdown]
# ## **Advanced Season Totals** - Pretty Useful

# %%
all_season_2019 = client.players_advanced_season_totals(season_end_year=2019)

# %%
type(all_season_2019)
# Out:
# list

# %%
import pandas as pd

# %%
df_2019 = pd.DataFrame(all_season_2019)
df_2019.head()
# Out:
#         slug          name                  positions  age  \
# 0  abrinal01  Álex Abrines  [Position.SHOOTING_GUARD]   25
# 1    acyqu01    Quincy Acy   [Position.POWER_FORWARD]   28
# 2  adamsja01  Jaylen Adams     [Position.POINT_GUARD]   22
# 3  adamsst01  Steven Adams          [Position.CENTER]   25
# 4  adebaba01   Bam Adebayo          [Position.CENTER]   21
#
#                          team  games_played  minutes_played  \
# 0  Team.OKLAHOMA_CITY_THUNDER            31             588
# 1           Team.PHOENIX_SUNS            10             123
# 2          Team.ATLANTA_HAWKS            34             428
# 3  Team.OKLAHOMA_CITY_THUNDER            80            2669
# 4             Team.MIAMI_HEAT            82            1913
#
#    player_efficiency_rating  true_shooting_percentage  \
# 0                       6.3                     0.507
# 1                       2.9                     0.379
# 2                       7.6                     0.474
# 3                      18.5                     0.591
# 4                      17.9                     0.623
#
#    three_point_attempt_rate  ...  turnover_percentage  usage_percentage  \
# 0                     0.809  ...                  7.9              12.2
# 1                     0.833  ...                 15.2               9.2
# 2                     0.673  ...                 19.7              13.5
# 3                     0.002  ...                 12.6              16.4
# 4                     0.031  ...                 17.1              15.8
#
#    offensive_win_shares  defensive_win_shares  win_shares  \
# 0                   0.1                   0.6         0.6
# 1                  -0.1                   0.0        -0.1
# 2                  -0.1                   0.2         0.1
# 3                   5.1                   4.0         9.1
# 4                   3.4                   3.4         6.8
#
#    win_shares_per_48_minutes  offensive_box_plus_minus  \
# 0                      0.053                      -2.4
# 1                     -0.022                      -5.7
# 2                      0.011                      -3.1
# 3                      0.163                       0.6
# 4                      0.171                      -0.6
#
#    defensive_box_plus_minus  box_plus_minus  value_over_replacement_player
# 0                      -0.9            -3.4                           -0.2
# 1                      -0.3            -5.9                           -0.1
# 2                      -1.3            -4.4                           -0.3
# 3                       2.1             2.7                            3.2
# 4                       3.6             3.0                            2.4
#
# [5 rows x 27 columns]

# %%
df_2019.to_csv('advanced_season_totals_2019.csv')

# %% [markdown]
# ## **Individual Game Play-By-Play** - Not very useful

# %%
pbp_20181016 = client.play_by_play(
    home_team=Team.BOSTON_CELTICS,
    year=2018,
    month=10,
    day=16,
)

# %%
df_20181016 = pd.DataFrame(pbp_20181016)

# %%
df_20181016.head(10)
# Out:
#    period         period_type  remaining_seconds_in_period  \
# 0       1  PeriodType.QUARTER                        700.0
# 1       1  PeriodType.QUARTER                        700.0
# 2       1  PeriodType.QUARTER                        675.0
# 3       1  PeriodType.QUARTER                        673.0
# 4       1  PeriodType.QUARTER                        668.0
# 5       1  PeriodType.QUARTER                        663.0
# 6       1  PeriodType.QUARTER                        658.0
# 7       1  PeriodType.QUARTER                        655.0
# 8       1  PeriodType.QUARTER                        636.0
# 9       1  PeriodType.QUARTER                        635.0
#
#              relevant_team                away_team            home_team  \
# 0  Team.PHILADELPHIA_76ERS  Team.PHILADELPHIA_76ERS  Team.BOSTON_CELTICS
# 1      Team.BOSTON_CELTICS  Team.PHILADELPHIA_76ERS  Team.BOSTON_CELTICS
# 2      Team.BOSTON_CELTICS  Team.PHILADELPHIA_76ERS  Team.BOSTON_CELTICS
# 3  Team.PHILADELPHIA_76ERS  Team.PHILADELPHIA_76ERS  Team.BOSTON_CELTICS
# 4  Team.PHILADELPHIA_76ERS  Team.PHILADELPHIA_76ERS  Team.BOSTON_CELTICS
# 5      Team.BOSTON_CELTICS  Team.PHILADELPHIA_76ERS  Team.BOSTON_CELTICS
# 6  Team.PHILADELPHIA_76ERS  Team.PHILADELPHIA_76ERS  Team.BOSTON_CELTICS
# 7  Team.PHILADELPHIA_76ERS  Team.PHILADELPHIA_76ERS  Team.BOSTON_CELTICS
# 8      Team.BOSTON_CELTICS  Team.PHILADELPHIA_76ERS  Team.BOSTON_CELTICS
# 9  Team.PHILADELPHIA_76ERS  Team.PHILADELPHIA_76ERS  Team.BOSTON_CELTICS
#
#    away_score  home_score                                        description
# 0           0           0      R. Covington misses 3-pt jump shot from 27 ft
# 1           0           0                          Defensive rebound by Team
# 2           0           0          J. Tatum misses 3-pt jump shot from 25 ft
# 3           0           0                      Defensive rebound by D. Šarić
# 4           0           0  Turnover by B. Simmons (bad pass; steal by G. ...
# 5           0           0               J. Brown misses 2-pt layup from 2 ft
# 6           0           0                    Defensive rebound by B. Simmons
# 7           2           0  J. Embiid makes 2-pt layup from 1 ft (assist b...
# 8           2           0               J. Tatum misses 2-pt layup from 5 ft
# 9           2           0                    Defensive rebound by B. Simmons

# %% [markdown]
# ## **Box Scores by Player** - Very Useful

# %%
westbrook2019 = client.regular_season_player_box_scores(
  player_identifier="westbru01",season_end_year=2019
 
)

# %%
df_westbrook2019 = pd.DataFrame(westbrook2019)
df_westbrook2019.head(10)
# Out:
#          date                        team       location  \
# 0  2018-10-21  Team.OKLAHOMA_CITY_THUNDER  Location.HOME
# 1  2018-10-25  Team.OKLAHOMA_CITY_THUNDER  Location.HOME
# 2  2018-10-28  Team.OKLAHOMA_CITY_THUNDER  Location.HOME
# 3  2018-10-30  Team.OKLAHOMA_CITY_THUNDER  Location.HOME
# 4  2018-11-01  Team.OKLAHOMA_CITY_THUNDER  Location.AWAY
# 5  2018-11-02  Team.OKLAHOMA_CITY_THUNDER  Location.AWAY
# 6  2018-11-05  Team.OKLAHOMA_CITY_THUNDER  Location.HOME
# 7  2018-11-19  Team.OKLAHOMA_CITY_THUNDER  Location.AWAY
# 8  2018-11-21  Team.OKLAHOMA_CITY_THUNDER  Location.AWAY
# 9  2018-11-23  Team.OKLAHOMA_CITY_THUNDER  Location.HOME
#
#                      opponent       outcome  seconds_played  made_field_goals  \
# 0       Team.SACRAMENTO_KINGS  Outcome.LOSS            2109                13
# 1         Team.BOSTON_CELTICS  Outcome.LOSS            1942                 5
# 2           Team.PHOENIX_SUNS   Outcome.WIN            1852                 8
# 3   Team.LOS_ANGELES_CLIPPERS   Outcome.WIN            2010                13
# 4      Team.CHARLOTTE_HORNETS   Outcome.WIN            2228                12
# 5     Team.WASHINGTON_WIZARDS   Outcome.WIN            1560                10
# 6   Team.NEW_ORLEANS_PELICANS   Outcome.WIN            1511                 6
# 7       Team.SACRAMENTO_KINGS  Outcome.LOSS            2194                12
# 8  Team.GOLDEN_STATE_WARRIORS   Outcome.WIN            1973                 5
# 9      Team.CHARLOTTE_HORNETS   Outcome.WIN            2082                10
#
#    attempted_field_goals  made_three_point_field_goals  \
# 0                     23                             1
# 1                     20                             0
# 2                     13                             0
# 3                     25                             1
# 4                     24                             0
# 5                     16                             0
# 6                     16                             0
# 7                     25                             4
# 8                     15                             1
# 9                     18                             1
#
#    attempted_three_point_field_goals  ...  offensive_rebounds  \
# 0                                  6  ...                   2
# 1                                  5  ...                   1
# 2                                  0  ...                   1
# 3                                  3  ...                   2
# 4                                  3  ...                   1
# 5                                  1  ...                   0
# 6                                  2  ...                   0
# 7                                 10  ...                   2
# 8                                  5  ...                   0
# 9                                  4  ...                   0
#
#    defensive_rebounds  assists  steals  blocks  turnovers  personal_fouls  \
# 0                  10        8       0       0          5               2
# 1                  14        8       0       0          5               5
# 2                   8        7       4       0          6               3
# 3                   2        8       3       1          3               4
# 4                   7       10       3       0          3               3
# 5                   3       12       4       0          1               1
# 6                   7        9       1       0          6               3
# 7                  11        7       3       0          4               5
# 8                  11       13       2       1          4               4
# 9                  12        8       2       0          4               3
#
#    points_scored  game_score  plus_minus
# 0             32        22.9         -13
# 1             13         3.7          -5
# 2             23        20.7           8
# 3             32        25.6          18
# 4             29        24.8           3
# 5             23        27.3          10
# 6             17         9.2          11
# 7             29        22.5           4
# 8             11        11.2          25
# 9             30        26.6          17
#
# [10 rows x 22 columns]

# %% [markdown]
# ## **Script to get Player Box Scores for period between years**

# %%
def box_score_df(player_id, year):
  df = pd.DataFrame(client.regular_season_player_box_scores(player_identifier=player_id,
  season_end_year=year))
  return df

def all_box_scores(player_id,year_start,year_stop):
    df = pd.concat([box_score_df(player_id, year) for year in range(year_start,year_stop)],
                   axis = 'rows',
                   join = 'inner')
    return df

# %%
import pandas as pd
from basketball_reference_web_scraper.data import Team
from basketball_reference_web_scraper import client

# %% [markdown]
# ### **Test for Russell Westbrooks box scores between 2014-2018

# %%
westbrook_4years = all_box_scores("westbru01",2015,2020)
print(westbrook_4years.head(10))
print(westbrook_4years.tail(10))
# Out:
#          date                        team       location  \
# 0  2014-10-29  Team.OKLAHOMA_CITY_THUNDER  Location.AWAY
# 1  2014-10-30  Team.OKLAHOMA_CITY_THUNDER  Location.AWAY
# 2  2014-11-28  Team.OKLAHOMA_CITY_THUNDER  Location.HOME
# 3  2014-12-02  Team.OKLAHOMA_CITY_THUNDER  Location.AWAY
# 4  2014-12-05  Team.OKLAHOMA_CITY_THUNDER  Location.AWAY
# 5  2014-12-07  Team.OKLAHOMA_CITY_THUNDER  Location.AWAY
# 6  2014-12-09  Team.OKLAHOMA_CITY_THUNDER  Location.HOME
# 7  2014-12-11  Team.OKLAHOMA_CITY_THUNDER  Location.HOME
# 8  2014-12-12  Team.OKLAHOMA_CITY_THUNDER  Location.AWAY
# 9  2014-12-14  Team.OKLAHOMA_CITY_THUNDER  Location.HOME
#
#                       opponent       outcome  seconds_played  \
# 0  Team.PORTLAND_TRAIL_BLAZERS  Outcome.LOSS            1959
# 1    Team.LOS_ANGELES_CLIPPERS  Outcome.LOSS             523
# 2         Team.NEW_YORK_KNICKS   Outcome.WIN            1428
# 3    Team.NEW_ORLEANS_PELICANS  Outcome.LOSS            1982
# 4      Team.PHILADELPHIA_76ERS   Outcome.WIN            1843
# 5         Team.DETROIT_PISTONS   Outcome.WIN            2080
# 6         Team.MILWAUKEE_BUCKS   Outcome.WIN            1927
# 7     Team.CLEVELAND_CAVALIERS   Outcome.WIN            2145
# 8  Team.MINNESOTA_TIMBERWOLVES   Outcome.WIN            2145
# 9            Team.PHOENIX_SUNS   Outcome.WIN            1591
#
#    made_field_goals  attempted_field_goals  made_three_point_field_goals  \
# 0                11                     26                             1
# 1                 1                      3                             0
# 2                12                     17                             3
# 3                 6                     20                             1
# 4                 8                     14                             1
# 5                 9                     19                             1
# 6                 8                     16                             0
# 7                12                     24                             0
# 8                12                     19                             2
# 9                 7                     18                             1
#
#    attempted_three_point_field_goals  ...  offensive_rebounds  \
# 0                                  2  ...                   2
# 1                                  1  ...                   0
# 2                                  4  ...                   4
# 3                                  4  ...                   1
# 4                                  3  ...                   0
# 5                                  3  ...                   1
# 6                                  2  ...                   2
# 7                                  2  ...                   1
# 8                                  3  ...                   1
# 9                                  4  ...                   4
#
#    defensive_rebounds  assists  steals  blocks  turnovers  personal_fouls  \
# 0                   1        6       3       0          2               3
# 1                   0        4       1       0          3               2
# 2                   3        8       1       0          3               2
# 3                   5        7       2       0          7               3
# 4                   5        7       2       0          6               3
# 5                  10        7       0       0          4               1
# 6                   3        7       3       0          5               5
# 7                   6        8       1       0          4               0
# 8                   5        6       2       0          4               3
# 9                   4        8       2       0          3               2
#
#    points_scored  game_score  plus_minus
# 0             38        29.5          -4
# 1              2         0.3          -3
# 2             32        30.6          24
# 3             21         9.9         -16
# 4             27        20.0          11
# 5             22        15.3          -9
# 6             28        22.0          24
# 7             26        19.1           5
# 8             34        28.3          16
# 9             28        26.0          17
#
# [10 rows x 22 columns]
#           date                        team       location  \
# 63  2019-03-22  Team.OKLAHOMA_CITY_THUNDER  Location.AWAY
# 64  2019-03-25  Team.OKLAHOMA_CITY_THUNDER  Location.AWAY
# 65  2019-03-27  Team.OKLAHOMA_CITY_THUNDER  Location.HOME
# 66  2019-03-29  Team.OKLAHOMA_CITY_THUNDER  Location.HOME
# 67  2019-03-31  Team.OKLAHOMA_CITY_THUNDER  Location.HOME
# 68  2019-04-02  Team.OKLAHOMA_CITY_THUNDER  Location.HOME
# 69  2019-04-05  Team.OKLAHOMA_CITY_THUNDER  Location.HOME
# 70  2019-04-07  Team.OKLAHOMA_CITY_THUNDER  Location.AWAY
# 71  2019-04-09  Team.OKLAHOMA_CITY_THUNDER  Location.HOME
# 72  2019-04-10  Team.OKLAHOMA_CITY_THUNDER  Location.AWAY
#
#                        opponent       outcome  seconds_played  \
# 63         Team.TORONTO_RAPTORS   Outcome.WIN            2206
# 64       Team.MEMPHIS_GRIZZLIES  Outcome.LOSS            2205
# 65          Team.INDIANA_PACERS   Outcome.WIN            2211
# 66          Team.DENVER_NUGGETS  Outcome.LOSS            2139
# 67        Team.DALLAS_MAVERICKS  Outcome.LOSS            2259
# 68      Team.LOS_ANGELES_LAKERS   Outcome.WIN            2208
# 69         Team.DETROIT_PISTONS   Outcome.WIN            2112
# 70  Team.MINNESOTA_TIMBERWOLVES   Outcome.WIN            2291
# 71         Team.HOUSTON_ROCKETS   Outcome.WIN            2224
# 72         Team.MILWAUKEE_BUCKS   Outcome.WIN            2188
#
#     made_field_goals  attempted_field_goals  made_three_point_field_goals  \
# 63                 6                     20                             2
# 64                 6                     20                             1
# 65                 6                     15                             2
# 66                11                     22                             1
# 67                 9                     19                             3
# 68                 8                     23                             2
# 69                 6                     18                             1
# 70                10                     22                             2
# 71                11                     23                             4
# 72                 7                     10                             1
#
#     attempted_three_point_field_goals  ...  offensive_rebounds  \
# 63                                  9  ...                   4
# 64                                  6  ...                   0
# 65                                  4  ...                   1
# 66                                  5  ...                   3
# 67                                  8  ...                   2
# 68                                  9  ...                   5
# 69                                  4  ...                   1
# 70                                  6  ...                   1
# 71                                 10  ...                   2
# 72                                  3  ...                   0
#
#     defensive_rebounds  assists  steals  blocks  turnovers  personal_fouls  \
# 63                   8       13       4       1          3               3
# 64                   5        7       0       0          1               3
# 65                  10       12       2       1          2               0
# 66                   6        9       2       0          3               3
# 67                   9       11       2       0          3               2
# 68                  15       21       3       0          2               2
# 69                   7       15       1       0          4               2
# 70                   9       15       1       0          4               3
# 71                  10       10       0       0          3               4
# 72                  11       17       1       1          4               3
#
#     points_scored  game_score  plus_minus
# 63             18        20.8          18
# 64             16         7.4         -20
# 65             17        21.3           8
# 66             27        23.6          -1
# 67             25        25.3          -3
# 68             20        29.6          24
# 69             19        16.7           4
# 70             27        24.5          -1
# 71             29        24.1           3
# 72             15        21.7           6
#
# [10 rows x 22 columns]

# %%
westbrook_4years.describe()
# Out:
#        seconds_played  made_field_goals  attempted_field_goals  \
# count      381.000000        381.000000             381.000000
# mean      2109.653543          9.170604              21.039370
# std        283.312698          3.558500               6.324641
# min        523.000000          0.000000               3.000000
# 25%       2015.000000          7.000000              17.000000
# 50%       2159.000000          9.000000              20.000000
# 75%       2258.000000         11.000000              25.000000
# max       3128.000000         21.000000              44.000000
#
#        made_three_point_field_goals  attempted_three_point_field_goals  \
# count                    381.000000                         381.000000
# mean                       1.582677                           5.115486
# std                        1.508437                           3.116560
# min                        0.000000                           0.000000
# 25%                        0.000000                           3.000000
# 50%                        1.000000                           5.000000
# 75%                        2.000000                           7.000000
# max                        8.000000                          16.000000
#
#        made_free_throws  attempted_free_throws  offensive_rebounds  \
# count        381.000000             381.000000          381.000000
# mean           6.388451               8.094488            1.750656
# std            3.803914               4.216072            1.333093
# min            0.000000               0.000000            0.000000
# 25%            3.000000               5.000000            1.000000
# 50%            6.000000               8.000000            2.000000
# 75%            9.000000              11.000000            3.000000
# max           19.000000              22.000000            7.000000
#
#        defensive_rebounds     assists      steals      blocks   turnovers  \
# count          381.000000  381.000000  381.000000  381.000000  381.000000
# mean             7.669291   10.110236    1.900262    0.309711    4.669291
# std              3.559395    3.636572    1.341847    0.560672    2.162072
# min              0.000000    0.000000    0.000000    0.000000    0.000000
# 25%              5.000000    7.000000    1.000000    0.000000    3.000000
# 50%              7.000000   10.000000    2.000000    0.000000    4.000000
# 75%             10.000000   12.000000    3.000000    1.000000    6.000000
# max             17.000000   24.000000    6.000000    2.000000   11.000000
#
#        personal_fouls  points_scored  game_score  plus_minus
# count      381.000000     381.000000  381.000000  381.000000
# mean         2.674541      26.312336   21.551969    4.737533
# std          1.428694       9.656717    8.572427   12.501974
# min          0.000000       0.000000   -4.000000  -36.000000
# 25%          2.000000      20.000000   16.000000   -4.000000
# 50%          3.000000      25.000000   21.700000    5.000000
# 75%          4.000000      32.000000   27.200000   14.000000
# max          6.000000      58.000000   45.600000   36.000000

# %%
westbrook_4years.to_csv('westbrook_2014_2019.csv')

# %%
schedule_2018 = client.season_schedule(season_end_year=2018)

# %%
df_schedule_2018 = pd.DataFrame(schedule_2018)
df_schedule_2018.head(10)
# Out:
#                  start_time                  away_team  \
# 0 2017-10-18 00:01:00+00:00        Team.BOSTON_CELTICS
# 1 2017-10-18 02:30:00+00:00       Team.HOUSTON_ROCKETS
# 2 2017-10-18 23:00:00+00:00     Team.CHARLOTTE_HORNETS
# 3 2017-10-18 23:00:00+00:00         Team.BROOKLYN_NETS
# 4 2017-10-18 23:00:00+00:00            Team.MIAMI_HEAT
# 5 2017-10-18 23:00:00+00:00    Team.PHILADELPHIA_76ERS
# 6 2017-10-18 23:30:00+00:00       Team.MILWAUKEE_BUCKS
# 7 2017-10-19 00:00:00+00:00  Team.NEW_ORLEANS_PELICANS
# 8 2017-10-19 00:30:00+00:00         Team.ATLANTA_HAWKS
# 9 2017-10-19 01:00:00+00:00        Team.DENVER_NUGGETS
#
#                     home_team  away_team_score  home_team_score
# 0    Team.CLEVELAND_CAVALIERS               99              102
# 1  Team.GOLDEN_STATE_WARRIORS              122              121
# 2        Team.DETROIT_PISTONS               90              102
# 3         Team.INDIANA_PACERS              131              140
# 4          Team.ORLANDO_MAGIC              109              116
# 5     Team.WASHINGTON_WIZARDS              115              120
# 6         Team.BOSTON_CELTICS              108              100
# 7      Team.MEMPHIS_GRIZZLIES               91              103
# 8       Team.DALLAS_MAVERICKS              117              111
# 9              Team.UTAH_JAZZ               96              106

# %%
df_schedule_2018.tail(100)
# Out:
#                     start_time                   away_team  \
# 1212 2018-04-10 23:00:00+00:00      Team.CHARLOTTE_HORNETS
# 1213 2018-04-10 23:30:00+00:00     Team.PHILADELPHIA_76ERS
# 1214 2018-04-11 00:00:00+00:00         Team.BOSTON_CELTICS
# 1215 2018-04-11 00:30:00+00:00           Team.PHOENIX_SUNS
# 1216 2018-04-11 01:00:00+00:00  Team.GOLDEN_STATE_WARRIORS
# ...                        ...                         ...
# 1307 2018-05-29 01:00:00+00:00  Team.GOLDEN_STATE_WARRIORS
# 1308 2018-06-01 01:00:00+00:00    Team.CLEVELAND_CAVALIERS
# 1309 2018-06-04 00:00:00+00:00    Team.CLEVELAND_CAVALIERS
# 1310 2018-06-07 01:00:00+00:00  Team.GOLDEN_STATE_WARRIORS
# 1311 2018-06-09 01:00:00+00:00  Team.GOLDEN_STATE_WARRIORS
#
#                        home_team  away_team_score  home_team_score
# 1212         Team.INDIANA_PACERS              119               93
# 1213          Team.ATLANTA_HAWKS              121              113
# 1214     Team.WASHINGTON_WIZARDS              101              113
# 1215       Team.DALLAS_MAVERICKS              124               97
# 1216              Team.UTAH_JAZZ               79              119
# ...                          ...              ...              ...
# 1307        Team.HOUSTON_ROCKETS              101               92
# 1308  Team.GOLDEN_STATE_WARRIORS              114              124
# 1309  Team.GOLDEN_STATE_WARRIORS              103              122
# 1310    Team.CLEVELAND_CAVALIERS              110              102
# 1311    Team.CLEVELAND_CAVALIERS              108               85
#
# [100 rows x 5 columns]

# %%
df_2020_schedule = pd.DataFrame(client.season_schedule(season_end_year=2020))

# %%
df_schedule_2018.shape
# Out:
# (1312, 5)

# %%
df_2020_schedule.shape
# Out:
# (1229, 5)

# %%
df_2020_schedule.tail(20)
# Out:
#                     start_time                    away_team  \
# 1209 2020-04-14 01:00:00+00:00        Team.DALLAS_MAVERICKS
# 1210 2020-04-14 02:30:00+00:00  Team.PORTLAND_TRAIL_BLAZERS
# 1211 2020-04-14 02:30:00+00:00  Team.MINNESOTA_TIMBERWOLVES
# 1212 2020-04-14 23:30:00+00:00         Team.TORONTO_RAPTORS
# 1213 2020-04-14 23:30:00+00:00         Team.DETROIT_PISTONS
# 1214 2020-04-15 02:00:00+00:00          Team.DENVER_NUGGETS
# 1215 2020-04-15 02:30:00+00:00        Team.SACRAMENTO_KINGS
# 1216 2020-04-15 23:30:00+00:00     Team.CLEVELAND_CAVALIERS
# 1217 2020-04-15 23:30:00+00:00           Team.CHICAGO_BULLS
# 1218 2020-04-15 23:30:00+00:00         Team.MILWAUKEE_BUCKS
# 1219 2020-04-15 23:30:00+00:00   Team.OKLAHOMA_CITY_THUNDER
# 1220 2020-04-15 23:30:00+00:00       Team.MEMPHIS_GRIZZLIES
# 1221 2020-04-15 23:30:00+00:00         Team.NEW_YORK_KNICKS
# 1222 2020-04-15 23:30:00+00:00         Team.TORONTO_RAPTORS
# 1223 2020-04-15 23:30:00+00:00       Team.CHARLOTTE_HORNETS
# 1224 2020-04-15 23:30:00+00:00    Team.NEW_ORLEANS_PELICANS
# 1225 2020-04-15 23:30:00+00:00          Team.INDIANA_PACERS
# 1226 2020-04-16 02:00:00+00:00      Team.LOS_ANGELES_LAKERS
# 1227 2020-04-16 02:00:00+00:00    Team.LOS_ANGELES_CLIPPERS
# 1228 2020-04-16 02:00:00+00:00   Team.GOLDEN_STATE_WARRIORS
#
#                         home_team  away_team_score  home_team_score
# 1209          Team.DENVER_NUGGETS              NaN              NaN
# 1210   Team.GOLDEN_STATE_WARRIORS              NaN              NaN
# 1211    Team.LOS_ANGELES_CLIPPERS              NaN              NaN
# 1212              Team.MIAMI_HEAT              NaN              NaN
# 1213         Team.NEW_YORK_KNICKS              NaN              NaN
# 1214               Team.UTAH_JAZZ              NaN              NaN
# 1215      Team.LOS_ANGELES_LAKERS              NaN              NaN
# 1216           Team.ATLANTA_HAWKS              NaN              NaN
# 1217          Team.BOSTON_CELTICS              NaN              NaN
# 1218           Team.BROOKLYN_NETS              NaN              NaN
# 1219        Team.DALLAS_MAVERICKS              NaN              NaN
# 1220         Team.HOUSTON_ROCKETS              NaN              NaN
# 1221  Team.MINNESOTA_TIMBERWOLVES              NaN              NaN
# 1222           Team.ORLANDO_MAGIC              NaN              NaN
# 1223      Team.PHILADELPHIA_76ERS              NaN              NaN
# 1224       Team.SAN_ANTONIO_SPURS              NaN              NaN
# 1225      Team.WASHINGTON_WIZARDS              NaN              NaN
# 1226            Team.PHOENIX_SUNS              NaN              NaN
# 1227  Team.PORTLAND_TRAIL_BLAZERS              NaN              NaN
# 1228        Team.SACRAMENTO_KINGS              NaN              NaN

# %%
client.player_box_scores
# Out:
# <function basketball_reference_web_scraper.client.player_box_scores(day, month, year, output_type=None, output_file_path=None, output_write_option=None, json_options=None)>

# %%
def allscores(day, month, year):
    df = pd.DataFrame(client.player_box_scores(day=day, month=month, year=year))
    return df

# %%
columns = allscores(2,1,2020).columns

# %% [raw]
# for i, j, k  in range(1,32), range(1,12), range(2012,2021):
#     date_list = [i,j,k]

# %%
client.player_box_scores(15,10,2016)
# Out:
# []

# %%
import datetime
from datetime import date
# date1 = 1,2,3
# date2 = date.today()
start = datetime.datetime(2013, 1, 1)
end = date.today()
mydates = pd.date_range(start, end)#.tolist()

# %%
def all_data(y, m, d):
    start = datetime.datetime(y, m, d)
    end = date.today()
    mydates = pd.date_range(start, end)#.tolist()

    for x in mydates:
        day = x.day
        month = x.month
        year = x.year
        allscores(day, month, year)

# %%
df = []
for x in mydates:
        day = x.day
        month = x.month
        year = x.year
        df.append(allscores(day, month, year))

# %%
joined = pd.DataFrame(columns = columns)

for x in range(len(df)):
    joined = pd.DataFrame.append(joined, df[x], ignore_index=True)

# %%
joined = pd.DataFrame.append(df[0], df[1], df,[2])

# %%
df[35]
# Out:
#           slug                name                        team       location  \
# 0    jokicni01        Nikola Jokić         Team.DENVER_NUGGETS  Location.AWAY
# 1    drumman01      Andre Drummond        Team.DETROIT_PISTONS  Location.HOME
# 2    youngtr01          Trae Young          Team.ATLANTA_HAWKS  Location.AWAY
# 3    lowryky01          Kyle Lowry        Team.TORONTO_RAPTORS  Location.HOME
# 4    porzikr01  Kristaps Porziņģis       Team.DALLAS_MAVERICKS  Location.HOME
# ..         ...                 ...                         ...            ...
# 177  mcgruro01     Rodney McGruder   Team.LOS_ANGELES_CLIPPERS  Location.HOME
# 178   bonejo01         Jordan Bone        Team.DETROIT_PISTONS  Location.HOME
# 179  jacksju01      Justin Jackson       Team.DALLAS_MAVERICKS  Location.HOME
# 180   exumda01          Dante Exum    Team.CLEVELAND_CAVALIERS  Location.AWAY
# 181  spellom01      Omari Spellman  Team.GOLDEN_STATE_WARRIORS  Location.AWAY
#
#                         opponent       outcome  seconds_played  \
# 0                 Team.UTAH_JAZZ   Outcome.WIN            2386
# 1              Team.PHOENIX_SUNS   Outcome.WIN            2288
# 2    Team.MINNESOTA_TIMBERWOLVES   Outcome.WIN            2231
# 3            Team.INDIANA_PACERS   Outcome.WIN            2252
# 4         Team.MEMPHIS_GRIZZLIES  Outcome.LOSS            1748
# ..                           ...           ...             ...
# 177              Team.MIAMI_HEAT   Outcome.WIN             409
# 178            Team.PHOENIX_SUNS   Outcome.WIN             438
# 179       Team.MEMPHIS_GRIZZLIES  Outcome.LOSS             862
# 180   Team.OKLAHOMA_CITY_THUNDER  Outcome.LOSS             892
# 181           Team.BROOKLYN_NETS  Outcome.LOSS            1666
#
#      made_field_goals  attempted_field_goals  made_three_point_field_goals  \
# 0                  14                     24                             0
# 1                  14                     19                             0
# 2                  10                     23                             6
# 3                  12                     21                             3
# 4                  10                     20                             5
# ..                ...                    ...                           ...
# 177                 0                      3                             0
# 178                 0                      3                             0
# 179                 1                      8                             1
# 180                 0                      1                             0
# 181                 0                      3                             0
#
#      ...  made_free_throws  attempted_free_throws  offensive_rebounds  \
# 0    ...                 2                      4                   6
# 1    ...                 3                      5                   7
# 2    ...                12                     13                   0
# 3    ...                 5                      5                   3
# 4    ...                 7                      7                   1
# ..   ...               ...                    ...                 ...
# 177  ...                 0                      0                   1
# 178  ...                 0                      0                   0
# 179  ...                 0                      0                   1
# 180  ...                 0                      0                   0
# 181  ...                 1                      4                   0
#
#      defensive_rebounds  assists  steals  blocks  turnovers  personal_fouls  \
# 0                    15       10       2       0          1               2
# 1                    12        4       3       0          3               1
# 2                     4       11       1       0          3               3
# 3                     5       10       2       0          3               3
# 4                    11        2       2       1          0               3
# ..                  ...      ...     ...     ...        ...             ...
# 177                   0        0       0       0          0               0
# 178                   1        1       0       0          0               1
# 179                   0        0       0       0          0               0
# 180                   2        2       1       0          4               3
# 181                   1        1       0       0          1               2
#
#      game_score
# 0          33.9
# 1          33.4
# 2          31.2
# 3          30.5
# 4          28.9
# ..          ...
# 177        -1.4
# 178        -1.5
# 179        -1.5
# 180        -2.9
# 181        -3.1
#
# [182 rows x 21 columns]

# %%
joined.to_csv('2013-2020.csv')

# %%
joined
# Out:
#              slug             name                        team       location  \
# 0       anthoca01  Carmelo Anthony        Team.NEW_YORK_KNICKS  Location.HOME
# 1       smithjo03       Josh Smith          Team.ATLANTA_HAWKS  Location.AWAY
# 2       holidjr01     Jrue Holiday     Team.PHILADELPHIA_76ERS  Location.AWAY
# 3       smithjr01       J.R. Smith        Team.NEW_YORK_KNICKS  Location.HOME
# 4       turneev01      Evan Turner     Team.PHILADELPHIA_76ERS  Location.AWAY
# ...           ...              ...                         ...            ...
# 200788  mcgruro01  Rodney McGruder   Team.LOS_ANGELES_CLIPPERS  Location.HOME
# 200789   bonejo01      Jordan Bone        Team.DETROIT_PISTONS  Location.HOME
# 200790  jacksju01   Justin Jackson       Team.DALLAS_MAVERICKS  Location.HOME
# 200791   exumda01       Dante Exum    Team.CLEVELAND_CAVALIERS  Location.AWAY
# 200792  spellom01   Omari Spellman  Team.GOLDEN_STATE_WARRIORS  Location.AWAY
#
#                            opponent       outcome seconds_played  \
# 0       Team.PORTLAND_TRAIL_BLAZERS  Outcome.LOSS           2472
# 1          Team.NEW_ORLEANS_HORNETS   Outcome.WIN           2234
# 2           Team.LOS_ANGELES_LAKERS   Outcome.WIN           2352
# 3       Team.PORTLAND_TRAIL_BLAZERS  Outcome.LOSS           2413
# 4           Team.LOS_ANGELES_LAKERS   Outcome.WIN           2455
# ...                             ...           ...            ...
# 200788              Team.MIAMI_HEAT   Outcome.WIN            409
# 200789            Team.PHOENIX_SUNS   Outcome.WIN            438
# 200790       Team.MEMPHIS_GRIZZLIES  Outcome.LOSS            862
# 200791   Team.OKLAHOMA_CITY_THUNDER  Outcome.LOSS            892
# 200792           Team.BROOKLYN_NETS  Outcome.LOSS           1666
#
#        made_field_goals attempted_field_goals made_three_point_field_goals  \
# 0                    14                    24                            5
# 1                    11                    20                            1
# 2                    10                    19                            2
# 3                    10                    22                            4
# 4                     8                    14                            2
# ...                 ...                   ...                          ...
# 200788                0                     3                            0
# 200789                0                     3                            0
# 200790                1                     8                            1
# 200791                0                     1                            0
# 200792                0                     3                            0
#
#         ... made_free_throws attempted_free_throws offensive_rebounds  \
# 0       ...               12                    14                  2
# 1       ...                0                     0                  2
# 2       ...                4                     4                  0
# 3       ...                4                     6                  3
# 4       ...                4                     7                  1
# ...     ...              ...                   ...                ...
# 200788  ...                0                     0                  1
# 200789  ...                0                     0                  0
# 200790  ...                0                     0                  1
# 200791  ...                0                     0                  0
# 200792  ...                1                     4                  0
#
#        defensive_rebounds assists steals blocks turnovers personal_fouls  \
# 0                       5       4      1      0         2              3
# 1                      11       7      3      4         1              2
# 2                       2      10      2      0         1              1
# 3                       8       5      3      0         2              2
# 4                      12       5      2      1         1              1
# ...                   ...     ...    ...    ...       ...            ...
# 200788                  0       0      0      0         0              0
# 200789                  1       1      0      0         0              1
# 200790                  0       0      0      0         0              0
# 200791                  2       2      1      0         4              3
# 200792                  1       1      0      0         1              2
#
#        game_score
# 0            36.5
# 1            27.0
# 2            24.9
# 3            24.0
# 4            23.3
# ...           ...
# 200788       -1.4
# 200789       -1.5
# 200790       -1.5
# 200791       -2.9
# 200792       -3.1
#
# [200793 rows x 21 columns]

# %%
dfs = pd.DataFrame(df[0])

# %%
dfs[0][2]
# Out:
#           slug                name                         team  \
# 0    davisan02       Anthony Davis      Team.LOS_ANGELES_LAKERS
# 1    hardeja01        James Harden         Team.HOUSTON_ROCKETS
# 2    simmobe01         Ben Simmons      Team.PHILADELPHIA_76ERS
# 3    capelca01        Clint Capela         Team.HOUSTON_ROCKETS
# 4    lillada01      Damian Lillard  Team.PORTLAND_TRAIL_BLAZERS
# ..         ...                 ...                          ...
# 115  harteis01  Isaiah Hartenstein         Team.HOUSTON_ROCKETS
# 116  diallch01       Cheick Diallo            Team.PHOENIX_SUNS
# 117  schofad01   Admiral Schofield      Team.WASHINGTON_WIZARDS
# 118  scottmi01          Mike Scott      Team.PHILADELPHIA_76ERS
# 119  herroty01         Tyler Herro              Team.MIAMI_HEAT
#
#           location                     opponent       outcome  seconds_played  \
# 0    Location.HOME    Team.NEW_ORLEANS_PELICANS   Outcome.WIN            2277
# 1    Location.HOME      Team.PHILADELPHIA_76ERS   Outcome.WIN            2449
# 2    Location.AWAY         Team.HOUSTON_ROCKETS  Outcome.LOSS            2532
# 3    Location.HOME      Team.PHILADELPHIA_76ERS   Outcome.WIN            2214
# 4    Location.AWAY      Team.WASHINGTON_WIZARDS   Outcome.WIN            2056
# ..             ...                          ...           ...             ...
# 115  Location.HOME      Team.PHILADELPHIA_76ERS   Outcome.WIN             666
# 116  Location.HOME         Team.NEW_YORK_KNICKS   Outcome.WIN             484
# 117  Location.HOME  Team.PORTLAND_TRAIL_BLAZERS  Outcome.LOSS             742
# 118  Location.AWAY         Team.HOUSTON_ROCKETS  Outcome.LOSS             721
# 119  Location.AWAY           Team.ORLANDO_MAGIC  Outcome.LOSS            1483
#
#      made_field_goals  attempted_field_goals  made_three_point_field_goals  \
# 0                  15                     21                             3
# 1                  13                     24                             6
# 2                  13                     20                             0
# 3                  12                     16                             0
# 4                  10                     20                             2
# ..                ...                    ...                           ...
# 115                 0                      2                             0
# 116                 0                      3                             0
# 117                 0                      3                             0
# 118                 0                      4                             0
# 119                 2                     11                             0
#
#      ...  made_free_throws  attempted_free_throws  offensive_rebounds  \
# 0    ...                13                     13                   2
# 1    ...                12                     12                   1
# 2    ...                 3                      7                   6
# 3    ...                 6                      8                   3
# 4    ...                13                     14                   0
# ..   ...               ...                    ...                 ...
# 115  ...                 0                      0                   0
# 116  ...                 0                      0                   1
# 117  ...                 1                      2                   0
# 118  ...                 0                      0                   0
# 119  ...                 0                      1                   1
#
#      defensive_rebounds  assists  steals  blocks  turnovers  personal_fouls  \
# 0                    11        1       3       1          3               3
# 1                    10       11       1       1          5               3
# 2                     7       11       3       4          3               5
# 3                    11        3       2       1          0               4
# 4                     3        3       1       0          1               1
# ..                  ...      ...     ...     ...        ...             ...
# 115                   2        1       0       0          0               2
# 116                   1        0       0       0          0               0
# 117                   2        0       0       0          0               2
# 118                   4        1       0       0          0               2
# 119                   4        1       1       0          2               1
#
#      game_score
# 0          42.2
# 1          39.3
# 2          33.4
# 3          31.4
# 4          27.2
# ..          ...
# 115        -0.9
# 116        -1.1
# 117        -1.7
# 118        -1.7
# 119        -2.1
#
# [120 rows x 21 columns]

# %%
df = all_data(2020, 2, 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-124-a6322427c4dd> in <module>
# ----> 1 df = all_data(2020, 2, 1)
#
# <ipython-input-123-fb89d30bc58c> in all_data(y, m, d)
#       9         month = x.month
#      10         year = x.year
# ---> 11         allscores(day, month, year)
#      12     return df
#
# <ipython-input-122-2220248e98e1> in allscores(day, month, year)
#       1 def allscores(day, month, year):
# ----> 2   df = pd.DataFrame.append(client.player_box_scores(day=day, month=month, year=year))
#       3   return df
#
# TypeError: append() missing 1 required positional argument: 'other'

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
westbrook_4years.to_csv('westbrook_2014_2019.csv')
