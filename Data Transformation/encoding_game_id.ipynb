# %% [markdown]
# # Cleaning and Encoding Game ID

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import datetime
import sys
sys.path.append('../Scripts')

# %% [markdown]
# ### Import Scripts

# %%
import box_score_functions as bfx
import scheduling_functions as sfx

# %% [markdown]
# ### Import Files

# %%
all_box_scores = pd.read_csv('../Resources/2013-2020.csv')
all_games = pd.read_csv('../Resources/game_schedule_13-current.csv')

# %% [markdown]
# ### Cleaning up the box scores

# %%
cleaned_box_scores = bfx.get_cleaned_box_scores(all_box_scores)

# %%
cleaned_box_scores.head(2)
# Out:
#         slug             name             Team Location  \
# 0  anthoca01  Carmelo Anthony  NEW_YORK_KNICKS     HOME
# 1  smithjo03       Josh Smith    ATLANTA_HAWKS     AWAY
#
#                  Opponent Outcome  seconds_played  made_field_goals  \
# 0  PORTLAND_TRAIL_BLAZERS    LOSS          2472.0              14.0
# 1     NEW_ORLEANS_HORNETS     WIN          2234.0              11.0
#
#    attempted_field_goals  made_three_point_field_goals  ...  \
# 0                   24.0                           5.0  ...
# 1                   20.0                           1.0  ...
#
#    attempted_free_throws  offensive_rebounds  defensive_rebounds  assists  \
# 0                   14.0                 2.0                 5.0      4.0
# 1                    0.0                 2.0                11.0      7.0
#
#    steals  blocks  turnovers  personal_fouls  game_score        date
# 0     1.0     0.0        2.0             3.0        36.5  2013-01-01
# 1     3.0     4.0        1.0             2.0        27.0  2013-01-01
#
# [2 rows x 22 columns]

# %%
sfx.what_is_this(cleaned_box_scores)
# Out:
# length : 200897
# <class 'pandas.core.frame.DataFrame'>
# slug                                  object
# name                                  object
# Team                                  object
# Location                              object
# Opponent                              object
# Outcome                               object
# seconds_played                       float64
# made_field_goals                     float64
# attempted_field_goals                float64
# made_three_point_field_goals         float64
# attempted_three_point_field_goals    float64
# made_free_throws                     float64
# attempted_free_throws                float64
# offensive_rebounds                   float64
# defensive_rebounds                   float64
# assists                              float64
# steals                               float64
# blocks                               float64
# turnovers                            float64
# personal_fouls                       float64
# game_score                           float64
# date                                  object
# dtype: object
#        seconds_played  made_field_goals  attempted_field_goals  \
# count   200897.000000     200897.000000          200897.000000
# mean      1372.277232          3.670299               8.059518
# std        642.770885          3.023112               5.649836
# min          0.000000          0.000000               0.000000
# 25%        910.000000          1.000000               4.000000
# 50%       1416.000000          3.000000               7.000000
# 75%       1884.000000          5.000000              11.000000
# max       3898.000000         24.000000              50.000000
#
#        made_three_point_field_goals  attempted_three_point_field_goals  \
# count                 200897.000000                      200897.000000
# mean                       0.881910                           2.475647
# std                        1.285492                           2.664410
# min                        0.000000                           0.000000
# 25%                        0.000000                           0.000000
# 50%                        0.000000                           2.000000
# 75%                        1.000000                           4.000000
# max                       14.000000                          24.000000
#
#        made_free_throws  attempted_free_throws  offensive_rebounds  \
# count     200897.000000          200897.000000       200897.000000
# mean           1.650647               2.168932            0.986172
# std            2.276783               2.785552            1.380716
# min            0.000000               0.000000            0.000000
# 25%            0.000000               0.000000            0.000000
# 50%            1.000000               2.000000            1.000000
# 75%            2.000000               4.000000            1.000000
# max           26.000000              39.000000           18.000000
#
#        defensive_rebounds        assists         steals         blocks  \
# count       200897.000000  200897.000000  200897.000000  200897.000000
# mean             3.138434       2.154582       0.727218       0.459733
# std              2.734978       2.484930       0.976820       0.848274
# min              0.000000       0.000000       0.000000       0.000000
# 25%              1.000000       0.000000       0.000000       0.000000
# 50%              3.000000       1.000000       0.000000       0.000000
# 75%              5.000000       3.000000       1.000000       1.000000
# max             23.000000      25.000000      10.000000      12.000000
#
#            turnovers  personal_fouls     game_score
# count  200897.000000   200897.000000  200897.000000
# mean        1.292862        1.926470       7.617937
# std         1.396002        1.468261       7.203976
# min         0.000000        0.000000      -9.500000
# 25%         0.000000        1.000000       2.000000
# 50%         1.000000        2.000000       6.300000
# 75%         2.000000        3.000000      11.800000
# max        12.000000        6.000000      56.600000

# %% [markdown]
# ### Cleaning up the Schedules

# %%
encoded_schedule = sfx.get_encoded_schedule(all_games)

# %%
encoded_schedule.head()
# Out:
#         date1       date2                away                 home  \
# 0  2012-10-30  2012-10-29  WASHINGTON_WIZARDS  CLEVELAND_CAVALIERS
# 1  2012-10-31  2012-10-30      BOSTON_CELTICS           MIAMI_HEAT
# 2  2012-10-31  2012-10-30    DALLAS_MAVERICKS   LOS_ANGELES_LAKERS
# 3  2012-10-31  2012-10-30      INDIANA_PACERS      TORONTO_RAPTORS
# 4  2012-10-31  2012-10-30      DENVER_NUGGETS   PHILADELPHIA_76ERS
#
#    away_team_score  home_team_score game_number game_id
# 0             84.0             94.0           0       0
# 1            107.0            120.0           1       1
# 2             99.0             91.0           2       2
# 3             90.0             88.0           3       3
# 4             75.0             84.0           4       4

# %% [markdown]
# ### Left Join Game ID's

# %%
# Make first encoder
encoder1 = encoded_schedule[['date1','home','game_id']].copy()
merge1_cols = ['date', 'Team','game_id1']
encoder1.columns = merge1_cols
encoder1.date = encoder1.date.astype('str')
encoder1.Team = encoder1.Team.astype('str')
encoder1.date = encoder1.date.str.strip()
encoder1.Team = encoder1.Team.str.strip()
encoder1.head(2)
# Out:
#          date                 Team game_id1
# 0  2012-10-30  CLEVELAND_CAVALIERS        0
# 1  2012-10-31           MIAMI_HEAT        1

# %%
# Make second encoder
encoder2 = encoded_schedule[['date1','away','game_id']].copy()
merge2_cols = ['date','Team','game_id2']
encoder2.columns = merge2_cols
encoder2.date = encoder2.date.astype('str')
encoder2.Team = encoder2.Team.astype('str')
encoder2.date = encoder2.date.str.strip()
encoder2.Team = encoder2.Team.str.strip()
encoder2.head(2)
# Out:
#          date                Team game_id2
# 0  2012-10-30  WASHINGTON_WIZARDS        0
# 1  2012-10-31      BOSTON_CELTICS        1

# %%
# Make second encoder
encoder3 = encoded_schedule[['date2','away','game_id']].copy()
merge3_cols = ['date','Team','game_id3']
encoder3.columns = merge3_cols
encoder3.date = encoder3.date.astype('str')
encoder3.Team = encoder3.Team.astype('str')
encoder3.date = encoder3.date.str.strip()
encoder3.Team = encoder3.Team.str.strip()
encoder3.head(2)
# Out:
#          date                Team game_id3
# 0  2012-10-29  WASHINGTON_WIZARDS        0
# 1  2012-10-30      BOSTON_CELTICS        1

# %%
encoder4 = encoded_schedule[['date2','home','game_id']].copy()
merge4_cols = ['date','Team','game_id4']
encoder4.columns = merge4_cols
encoder4.date = encoder4.date.astype('str')
encoder4.Team = encoder4.Team.astype('str')
encoder4.date = encoder4.date.str.strip()
encoder4.Team = encoder4.Team.str.strip()
encoder4.head(2)
# Out:
#          date                 Team game_id4
# 0  2012-10-29  CLEVELAND_CAVALIERS        0
# 1  2012-10-30           MIAMI_HEAT        1

# %%
cleaned_box_scores.date = cleaned_box_scores.date.astype('str')
cleaned_box_scores.Team = cleaned_box_scores.Team.astype('str')
cleaned_box_scores.date = cleaned_box_scores.date.str.strip()
cleaned_box_scores.Team = cleaned_box_scores.Team.str.strip()

# %%
quarter_encoded_box_scores = pd.merge(cleaned_box_scores,encoder1, on=['date','Team'], how='left')
quarter_encoded_box_scores.head(3)
# Out:
#         slug             name                Team Location  \
# 0  anthoca01  Carmelo Anthony     NEW_YORK_KNICKS     HOME
# 1  smithjo03       Josh Smith       ATLANTA_HAWKS     AWAY
# 2  holidjr01     Jrue Holiday  PHILADELPHIA_76ERS     AWAY
#
#                  Opponent Outcome  seconds_played  made_field_goals  \
# 0  PORTLAND_TRAIL_BLAZERS    LOSS          2472.0              14.0
# 1     NEW_ORLEANS_HORNETS     WIN          2234.0              11.0
# 2      LOS_ANGELES_LAKERS     WIN          2352.0              10.0
#
#    attempted_field_goals  made_three_point_field_goals  ...  \
# 0                   24.0                           5.0  ...
# 1                   20.0                           1.0  ...
# 2                   19.0                           2.0  ...
#
#    offensive_rebounds  defensive_rebounds  assists  steals  blocks  turnovers  \
# 0                 2.0                 5.0      4.0     1.0     0.0        2.0
# 1                 2.0                11.0      7.0     3.0     4.0        1.0
# 2                 0.0                 2.0     10.0     2.0     0.0        1.0
#
#    personal_fouls  game_score        date  game_id1
# 0             3.0        36.5  2013-01-01       NaN
# 1             2.0        27.0  2013-01-01       NaN
# 2             1.0        24.9  2013-01-01       NaN
#
# [3 rows x 23 columns]

# %%
half_encoded_box_scores = pd.merge(quarter_encoded_box_scores,encoder2, on=['date','Team'], how='left')
half_encoded_box_scores.head(3)
# Out:
#         slug             name                Team Location  \
# 0  anthoca01  Carmelo Anthony     NEW_YORK_KNICKS     HOME
# 1  smithjo03       Josh Smith       ATLANTA_HAWKS     AWAY
# 2  holidjr01     Jrue Holiday  PHILADELPHIA_76ERS     AWAY
#
#                  Opponent Outcome  seconds_played  made_field_goals  \
# 0  PORTLAND_TRAIL_BLAZERS    LOSS          2472.0              14.0
# 1     NEW_ORLEANS_HORNETS     WIN          2234.0              11.0
# 2      LOS_ANGELES_LAKERS     WIN          2352.0              10.0
#
#    attempted_field_goals  made_three_point_field_goals  ...  \
# 0                   24.0                           5.0  ...
# 1                   20.0                           1.0  ...
# 2                   19.0                           2.0  ...
#
#    defensive_rebounds  assists  steals  blocks  turnovers  personal_fouls  \
# 0                 5.0      4.0     1.0     0.0        2.0             3.0
# 1                11.0      7.0     3.0     4.0        1.0             2.0
# 2                 2.0     10.0     2.0     0.0        1.0             1.0
#
#    game_score        date  game_id1  game_id2
# 0        36.5  2013-01-01       NaN       NaN
# 1        27.0  2013-01-01       NaN       453
# 2        24.9  2013-01-01       NaN       NaN
#
# [3 rows x 24 columns]

# %%
three_q_encoded_box_scores = pd.merge(half_encoded_box_scores,encoder3, on = ['date','Team'], how='left')
three_q_encoded_box_scores.head(3)
# Out:
#         slug             name                Team Location  \
# 0  anthoca01  Carmelo Anthony     NEW_YORK_KNICKS     HOME
# 1  smithjo03       Josh Smith       ATLANTA_HAWKS     AWAY
# 2  holidjr01     Jrue Holiday  PHILADELPHIA_76ERS     AWAY
#
#                  Opponent Outcome  seconds_played  made_field_goals  \
# 0  PORTLAND_TRAIL_BLAZERS    LOSS          2472.0              14.0
# 1     NEW_ORLEANS_HORNETS     WIN          2234.0              11.0
# 2      LOS_ANGELES_LAKERS     WIN          2352.0              10.0
#
#    attempted_field_goals  made_three_point_field_goals  ...  assists  steals  \
# 0                   24.0                           5.0  ...      4.0     1.0
# 1                   20.0                           1.0  ...      7.0     3.0
# 2                   19.0                           2.0  ...     10.0     2.0
#
#    blocks  turnovers  personal_fouls  game_score        date  game_id1  \
# 0     0.0        2.0             3.0        36.5  2013-01-01       NaN
# 1     4.0        1.0             2.0        27.0  2013-01-01       NaN
# 2     0.0        1.0             1.0        24.9  2013-01-01       NaN
#
#    game_id2  game_id3
# 0       NaN       NaN
# 1       453       459
# 2       NaN       461
#
# [3 rows x 25 columns]

# %%
fully_encoded_box_scores = pd.merge(three_q_encoded_box_scores,encoder4, on = ['date','Team'], how='left')
fully_encoded_box_scores.head(3)
# Out:
#         slug             name                Team Location  \
# 0  anthoca01  Carmelo Anthony     NEW_YORK_KNICKS     HOME
# 1  smithjo03       Josh Smith       ATLANTA_HAWKS     AWAY
# 2  holidjr01     Jrue Holiday  PHILADELPHIA_76ERS     AWAY
#
#                  Opponent Outcome  seconds_played  made_field_goals  \
# 0  PORTLAND_TRAIL_BLAZERS    LOSS          2472.0              14.0
# 1     NEW_ORLEANS_HORNETS     WIN          2234.0              11.0
# 2      LOS_ANGELES_LAKERS     WIN          2352.0              10.0
#
#    attempted_field_goals  made_three_point_field_goals  ...  steals  blocks  \
# 0                   24.0                           5.0  ...     1.0     0.0
# 1                   20.0                           1.0  ...     3.0     4.0
# 2                   19.0                           2.0  ...     2.0     0.0
#
#    turnovers  personal_fouls  game_score        date  game_id1  game_id2  \
# 0        2.0             3.0        36.5  2013-01-01       NaN       NaN
# 1        1.0             2.0        27.0  2013-01-01       NaN       453
# 2        1.0             1.0        24.9  2013-01-01       NaN       NaN
#
#    game_id3  game_id4
# 0       NaN       458
# 1       459       NaN
# 2       461       NaN
#
# [3 rows x 26 columns]

# %%
game_id_matrix = fully_encoded_box_scores[['game_id1','game_id2','game_id3','game_id4']].copy()

# %%
len(game_id_matrix)
# Out:
# 202219

# %%
checking_for_null = game_id_matrix.dropna(axis=1, how = 'all')
len(checking_for_null)
# Out:
# 202219

# %% [markdown]
# ## Each Box score was assigned at least 1 game_id
