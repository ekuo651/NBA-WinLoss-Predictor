# %% [markdown]
# # Cleaning and Encoding Game ID

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import datetime
import sys
sys.path.append('../Scripts')

# %% [markdown]
# ### Import Scripts

# %%
import box_score_functions as bfx
import scheduling_functions as sfx

# %% [markdown]
# ### Import Files

# %%
all_box_scores = pd.read_csv('../Resources/2013-2020.csv')
all_games = pd.read_csv('../Resources/game_schedule_13-current.csv')

# %% [markdown]
# ### Cleaning up the box scores

# %%
cleaned_box_scores = bfx.get_cleaned_box_scores(all_box_scores)

# %%
cleaned_box_scores.head(2)
# Out:
#         slug             name             Team Location  \
# 0  anthoca01  Carmelo Anthony  NEW_YORK_KNICKS     HOME
# 1  smithjo03       Josh Smith    ATLANTA_HAWKS     AWAY
#
#                  Opponent Outcome  seconds_played  made_field_goals  \
# 0  PORTLAND_TRAIL_BLAZERS    LOSS          2472.0              14.0
# 1     NEW_ORLEANS_HORNETS     WIN          2234.0              11.0
#
#    attempted_field_goals  made_three_point_field_goals  ...  \
# 0                   24.0                           5.0  ...
# 1                   20.0                           1.0  ...
#
#    attempted_free_throws  offensive_rebounds  defensive_rebounds  assists  \
# 0                   14.0                 2.0                 5.0      4.0
# 1                    0.0                 2.0                11.0      7.0
#
#    steals  blocks  turnovers  personal_fouls  game_score        date
# 0     1.0     0.0        2.0             3.0        36.5  2013-01-01
# 1     3.0     4.0        1.0             2.0        27.0  2013-01-01
#
# [2 rows x 22 columns]

# %%
sfx.what_is_this(cleaned_box_scores)
# Out:
# length : 200897
# <class 'pandas.core.frame.DataFrame'>
# slug                                  object
# name                                  object
# Team                                  object
# Location                              object
# Opponent                              object
# Outcome                               object
# seconds_played                       float64
# made_field_goals                     float64
# attempted_field_goals                float64
# made_three_point_field_goals         float64
# attempted_three_point_field_goals    float64
# made_free_throws                     float64
# attempted_free_throws                float64
# offensive_rebounds                   float64
# defensive_rebounds                   float64
# assists                              float64
# steals                               float64
# blocks                               float64
# turnovers                            float64
# personal_fouls                       float64
# game_score                           float64
# date                                  object
# dtype: object
#        seconds_played  made_field_goals  attempted_field_goals  \
# count   200897.000000     200897.000000          200897.000000
# mean      1372.277232          3.670299               8.059518
# std        642.770885          3.023112               5.649836
# min          0.000000          0.000000               0.000000
# 25%        910.000000          1.000000               4.000000
# 50%       1416.000000          3.000000               7.000000
# 75%       1884.000000          5.000000              11.000000
# max       3898.000000         24.000000              50.000000
#
#        made_three_point_field_goals  attempted_three_point_field_goals  \
# count                 200897.000000                      200897.000000
# mean                       0.881910                           2.475647
# std                        1.285492                           2.664410
# min                        0.000000                           0.000000
# 25%                        0.000000                           0.000000
# 50%                        0.000000                           2.000000
# 75%                        1.000000                           4.000000
# max                       14.000000                          24.000000
#
#        made_free_throws  attempted_free_throws  offensive_rebounds  \
# count     200897.000000          200897.000000       200897.000000
# mean           1.650647               2.168932            0.986172
# std            2.276783               2.785552            1.380716
# min            0.000000               0.000000            0.000000
# 25%            0.000000               0.000000            0.000000
# 50%            1.000000               2.000000            1.000000
# 75%            2.000000               4.000000            1.000000
# max           26.000000              39.000000           18.000000
#
#        defensive_rebounds        assists         steals         blocks  \
# count       200897.000000  200897.000000  200897.000000  200897.000000
# mean             3.138434       2.154582       0.727218       0.459733
# std              2.734978       2.484930       0.976820       0.848274
# min              0.000000       0.000000       0.000000       0.000000
# 25%              1.000000       0.000000       0.000000       0.000000
# 50%              3.000000       1.000000       0.000000       0.000000
# 75%              5.000000       3.000000       1.000000       1.000000
# max             23.000000      25.000000      10.000000      12.000000
#
#            turnovers  personal_fouls     game_score
# count  200897.000000   200897.000000  200897.000000
# mean        1.292862        1.926470       7.617937
# std         1.396002        1.468261       7.203976
# min         0.000000        0.000000      -9.500000
# 25%         0.000000        1.000000       2.000000
# 50%         1.000000        2.000000       6.300000
# 75%         2.000000        3.000000      11.800000
# max        12.000000        6.000000      56.600000

# %% [markdown]
# ### Cleaning up the Schedules

# %%
encoded_schedule = sfx.get_encoded_schedule(all_games)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-e58edb378e3e> in <module>
# ----> 1 encoded_schedule = sfx.get_encoded_schedule(all_games)
#
# ~\Project-3\Scripts\scheduling_functions.py in get_encoded_schedule(df)
#      43
#      44 def get_encoded_schedule(df):
# ---> 45     new_df = schedule_encoder(schedule_organizer(schedule_cleaner(define_types(calculate_endtime(df)))))
#      46     return new_df
#      47
#
# ~\Project-3\Scripts\scheduling_functions.py in schedule_encoder(df)
#      39 def schedule_encoder(df):
#      40     df['game_id'] = df.index
# ---> 41     df.game_number = df.game_number.astype('str')
#      42     return df
#      43
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5178             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5179                 return self[name]
# -> 5180             return object.__getattribute__(self, name)
#    5181
#    5182     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'game_number'

# %%
encoded_schedule.head()
# Out:
#         date1       date2                away                 home  \
# 0  2012-10-30  2012-10-29  WASHINGTON_WIZARDS  CLEVELAND_CAVALIERS
# 1  2012-10-31  2012-10-30      BOSTON_CELTICS           MIAMI_HEAT
# 2  2012-10-31  2012-10-30    DALLAS_MAVERICKS   LOS_ANGELES_LAKERS
# 3  2012-10-31  2012-10-30      INDIANA_PACERS      TORONTO_RAPTORS
# 4  2012-10-31  2012-10-30      DENVER_NUGGETS   PHILADELPHIA_76ERS
#
#    away_team_score  home_team_score game_number game_id
# 0             84.0             94.0           0       0
# 1            107.0            120.0           1       1
# 2             99.0             91.0           2       2
# 3             90.0             88.0           3       3
# 4             75.0             84.0           4       4

# %%
encoded_schedule.to_csv('../Resources/encoded_schedule.csv')

# %% [markdown]
# ### Left Join Game ID's

# %%
# Make first encoder
encoder1 = encoded_schedule[['date1','home','game_id']].copy()
merge1_cols = ['date', 'Team','game_id1']
encoder1.columns = merge1_cols
encoder1.date = encoder1.date.astype('str')
encoder1.Team = encoder1.Team.astype('str')
encoder1.date = encoder1.date.str.strip()
encoder1.Team = encoder1.Team.str.strip()
encoder1.head(2)
# Out:
#          date                 Team game_id1
# 0  2012-10-30  CLEVELAND_CAVALIERS        0
# 1  2012-10-31           MIAMI_HEAT        1

# %%
# Make second encoder
encoder2 = encoded_schedule[['date1','away','game_id']].copy()
merge2_cols = ['date','Team','game_id2']
encoder2.columns = merge2_cols
encoder2.date = encoder2.date.astype('str')
encoder2.Team = encoder2.Team.astype('str')
encoder2.date = encoder2.date.str.strip()
encoder2.Team = encoder2.Team.str.strip()
encoder2.head(2)
# Out:
#          date                Team game_id2
# 0  2012-10-30  WASHINGTON_WIZARDS        0
# 1  2012-10-31      BOSTON_CELTICS        1

# %%
# Make second encoder
encoder3 = encoded_schedule[['date2','away','game_id']].copy()
merge3_cols = ['date','Team','game_id3']
encoder3.columns = merge3_cols
encoder3.date = encoder3.date.astype('str')
encoder3.Team = encoder3.Team.astype('str')
encoder3.date = encoder3.date.str.strip()
encoder3.Team = encoder3.Team.str.strip()
encoder3.head(2)
# Out:
#          date                Team game_id3
# 0  2012-10-29  WASHINGTON_WIZARDS        0
# 1  2012-10-30      BOSTON_CELTICS        1

# %%
encoder4 = encoded_schedule[['date2','home','game_id']].copy()
merge4_cols = ['date','Team','game_id4']
encoder4.columns = merge4_cols
encoder4.date = encoder4.date.astype('str')
encoder4.Team = encoder4.Team.astype('str')
encoder4.date = encoder4.date.str.strip()
encoder4.Team = encoder4.Team.str.strip()
encoder4.head(2)
# Out:
#          date                 Team game_id4
# 0  2012-10-29  CLEVELAND_CAVALIERS        0
# 1  2012-10-30           MIAMI_HEAT        1

# %%
cleaned_box_scores.date = cleaned_box_scores.date.astype('str')
cleaned_box_scores.Team = cleaned_box_scores.Team.astype('str')
cleaned_box_scores.date = cleaned_box_scores.date.str.strip()
cleaned_box_scores.Team = cleaned_box_scores.Team.str.strip()

# %%
quarter_encoded_box_scores = pd.merge(cleaned_box_scores,encoder1, on=['date','Team'], how='left')
quarter_encoded_box_scores.head(3)
# Out:
#         slug             name                Team Location  \
# 0  anthoca01  Carmelo Anthony     NEW_YORK_KNICKS     HOME
# 1  smithjo03       Josh Smith       ATLANTA_HAWKS     AWAY
# 2  holidjr01     Jrue Holiday  PHILADELPHIA_76ERS     AWAY
#
#                  Opponent Outcome  seconds_played  made_field_goals  \
# 0  PORTLAND_TRAIL_BLAZERS    LOSS          2472.0              14.0
# 1     NEW_ORLEANS_HORNETS     WIN          2234.0              11.0
# 2      LOS_ANGELES_LAKERS     WIN          2352.0              10.0
#
#    attempted_field_goals  made_three_point_field_goals  ...  \
# 0                   24.0                           5.0  ...
# 1                   20.0                           1.0  ...
# 2                   19.0                           2.0  ...
#
#    offensive_rebounds  defensive_rebounds  assists  steals  blocks  turnovers  \
# 0                 2.0                 5.0      4.0     1.0     0.0        2.0
# 1                 2.0                11.0      7.0     3.0     4.0        1.0
# 2                 0.0                 2.0     10.0     2.0     0.0        1.0
#
#    personal_fouls  game_score        date  game_id1
# 0             3.0        36.5  2013-01-01       NaN
# 1             2.0        27.0  2013-01-01       NaN
# 2             1.0        24.9  2013-01-01       NaN
#
# [3 rows x 23 columns]

# %%
half_encoded_box_scores = pd.merge(quarter_encoded_box_scores,encoder2, on=['date','Team'], how='left')
half_encoded_box_scores.head(3)
# Out:
#         slug             name                Team Location  \
# 0  anthoca01  Carmelo Anthony     NEW_YORK_KNICKS     HOME
# 1  smithjo03       Josh Smith       ATLANTA_HAWKS     AWAY
# 2  holidjr01     Jrue Holiday  PHILADELPHIA_76ERS     AWAY
#
#                  Opponent Outcome  seconds_played  made_field_goals  \
# 0  PORTLAND_TRAIL_BLAZERS    LOSS          2472.0              14.0
# 1     NEW_ORLEANS_HORNETS     WIN          2234.0              11.0
# 2      LOS_ANGELES_LAKERS     WIN          2352.0              10.0
#
#    attempted_field_goals  made_three_point_field_goals  ...  \
# 0                   24.0                           5.0  ...
# 1                   20.0                           1.0  ...
# 2                   19.0                           2.0  ...
#
#    defensive_rebounds  assists  steals  blocks  turnovers  personal_fouls  \
# 0                 5.0      4.0     1.0     0.0        2.0             3.0
# 1                11.0      7.0     3.0     4.0        1.0             2.0
# 2                 2.0     10.0     2.0     0.0        1.0             1.0
#
#    game_score        date  game_id1  game_id2
# 0        36.5  2013-01-01       NaN       NaN
# 1        27.0  2013-01-01       NaN       453
# 2        24.9  2013-01-01       NaN       NaN
#
# [3 rows x 24 columns]

# %%
three_q_encoded_box_scores = pd.merge(half_encoded_box_scores,encoder3, on = ['date','Team'], how='left')
three_q_encoded_box_scores.head(3)
# Out:
#         slug             name                Team Location  \
# 0  anthoca01  Carmelo Anthony     NEW_YORK_KNICKS     HOME
# 1  smithjo03       Josh Smith       ATLANTA_HAWKS     AWAY
# 2  holidjr01     Jrue Holiday  PHILADELPHIA_76ERS     AWAY
#
#                  Opponent Outcome  seconds_played  made_field_goals  \
# 0  PORTLAND_TRAIL_BLAZERS    LOSS          2472.0              14.0
# 1     NEW_ORLEANS_HORNETS     WIN          2234.0              11.0
# 2      LOS_ANGELES_LAKERS     WIN          2352.0              10.0
#
#    attempted_field_goals  made_three_point_field_goals  ...  assists  steals  \
# 0                   24.0                           5.0  ...      4.0     1.0
# 1                   20.0                           1.0  ...      7.0     3.0
# 2                   19.0                           2.0  ...     10.0     2.0
#
#    blocks  turnovers  personal_fouls  game_score        date  game_id1  \
# 0     0.0        2.0             3.0        36.5  2013-01-01       NaN
# 1     4.0        1.0             2.0        27.0  2013-01-01       NaN
# 2     0.0        1.0             1.0        24.9  2013-01-01       NaN
#
#    game_id2  game_id3
# 0       NaN       NaN
# 1       453       459
# 2       NaN       461
#
# [3 rows x 25 columns]

# %%
fully_encoded_box_scores = pd.merge(three_q_encoded_box_scores,encoder4, on = ['date','Team'], how='left')
fully_encoded_box_scores.head(3)
# Out:
#         slug             name                Team Location  \
# 0  anthoca01  Carmelo Anthony     NEW_YORK_KNICKS     HOME
# 1  smithjo03       Josh Smith       ATLANTA_HAWKS     AWAY
# 2  holidjr01     Jrue Holiday  PHILADELPHIA_76ERS     AWAY
#
#                  Opponent Outcome  seconds_played  made_field_goals  \
# 0  PORTLAND_TRAIL_BLAZERS    LOSS          2472.0              14.0
# 1     NEW_ORLEANS_HORNETS     WIN          2234.0              11.0
# 2      LOS_ANGELES_LAKERS     WIN          2352.0              10.0
#
#    attempted_field_goals  made_three_point_field_goals  ...  steals  blocks  \
# 0                   24.0                           5.0  ...     1.0     0.0
# 1                   20.0                           1.0  ...     3.0     4.0
# 2                   19.0                           2.0  ...     2.0     0.0
#
#    turnovers  personal_fouls  game_score        date  game_id1  game_id2  \
# 0        2.0             3.0        36.5  2013-01-01       NaN       NaN
# 1        1.0             2.0        27.0  2013-01-01       NaN       453
# 2        1.0             1.0        24.9  2013-01-01       NaN       NaN
#
#    game_id3  game_id4
# 0       NaN       458
# 1       459       NaN
# 2       461       NaN
#
# [3 rows x 26 columns]

# %%
fully_encoded_box_scores.to_csv('../Resources/fully_encoded_box_scores_raw.csv')

# %%
game_id_matrix = fully_encoded_box_scores[['game_id1','game_id2','game_id3','game_id4']].copy()

len(game_id_matrix)
# Out:
# 202219

# %%
checking_for_null = game_id_matrix.dropna(axis=1, how = 'all')
len(checking_for_null)
# Out:
# 202219

# %% [markdown]
# ## Each Box score was assigned at least 1 game_id

# %%
fully_encoded_box_scores.columns
# Out:
# Index(['slug', 'name', 'Team', 'Location', 'Opponent', 'Outcome',
#        'seconds_played', 'made_field_goals', 'attempted_field_goals',
#        'made_three_point_field_goals', 'attempted_three_point_field_goals',
#        'made_free_throws', 'attempted_free_throws', 'offensive_rebounds',
#        'defensive_rebounds', 'assists', 'steals', 'blocks', 'turnovers',
#        'personal_fouls', 'game_score', 'date', 'game_id1', 'game_id2',
#        'game_id3', 'game_id4'],
#       dtype='object')

# %%
fully_encoded_box_scores[['slug', 'name', 'Team', 'Location', 'Opponent', 'Outcome','date', 'game_id1', 'game_id2',
       'game_id3', 'game_id4']].sample(50)
# Out:
#              slug              name                    Team Location  \
# 99389   sefolth01   Thabo Sefolosha           ATLANTA_HAWKS     AWAY
# 46705   thornma01   Marcus Thornton          BOSTON_CELTICS     AWAY
# 1215    ellismo01       Monta Ellis         MILWAUKEE_BUCKS     HOME
# 27780   bennean01   Anthony Bennett     CLEVELAND_CAVALIERS     AWAY
# 30040   youngni01        Nick Young      LOS_ANGELES_LAKERS     AWAY
# 34172   anderch01    Chris Andersen              MIAMI_HEAT     AWAY
# 5893    georgpa01       Paul George          INDIANA_PACERS     HOME
# 87385   johnsch04     Chris Johnson               UTAH_JAZZ     AWAY
# 95312    foyera01        Randy Foye   OKLAHOMA_CITY_THUNDER     AWAY
# 44474   ibakase01       Serge Ibaka   OKLAHOMA_CITY_THUNDER     HOME
# 55262   roberbr01     Brian Roberts       CHARLOTTE_HORNETS     HOME
# 150273  bullore01    Reggie Bullock         DETROIT_PISTONS     HOME
# 56312   snellto01        Tony Snell           CHICAGO_BULLS     HOME
# 2322    mahinia01       Ian Mahinmi          INDIANA_PACERS     AWAY
# 24910   lopezbr01       Brook Lopez           BROOKLYN_NETS     HOME
# 173342  oubreke01       Kelly Oubre            PHOENIX_SUNS     AWAY
# 54474   pargoja01     Jannero Pargo       CHARLOTTE_HORNETS     HOME
# 131782  smartma01      Marcus Smart          BOSTON_CELTICS     HOME
# 50672   plumlmi01     Miles Plumlee            PHOENIX_SUNS     AWAY
# 197248  morrima03     Marcus Morris         NEW_YORK_KNICKS     AWAY
# 95530   bullore01    Reggie Bullock         DETROIT_PISTONS     HOME
# 6148    gallida01  Danilo Gallinari          DENVER_NUGGETS     AWAY
# 200645  butleji01      Jimmy Butler              MIAMI_HEAT     HOME
# 33422   blatcan01    Andray Blatche           BROOKLYN_NETS     HOME
# 89692    hillso01      Solomon Hill          INDIANA_PACERS     AWAY
# 4964    priceaj01        A.J. Price      WASHINGTON_WIZARDS     AWAY
# 51282    bealbr01      Bradley Beal      WASHINGTON_WIZARDS     HOME
# 56878   jerebjo01     Jonas Jerebko         DETROIT_PISTONS     AWAY
# 184721  powelno01     Norman Powell         TORONTO_RAPTORS     AWAY
# 36583    walljo01         John Wall      WASHINGTON_WIZARDS     HOME
# 88202   greendr01    Draymond Green   GOLDEN_STATE_WARRIORS     HOME
# 54915   vucevni01    Nikola Vučević           ORLANDO_MAGIC     HOME
# 26645   zelleco01       Cody Zeller       CHARLOTTE_BOBCATS     HOME
# 54272   willish03   Shawne Williams              MIAMI_HEAT     HOME
# 174858  mccolcj01       CJ McCollum  PORTLAND_TRAIL_BLAZERS     HOME
# 93323   karasse01    Sergey Karasev           BROOKLYN_NETS     AWAY
# 188528  wallaty01    Tyrone Wallace           ATLANTA_HAWKS     HOME
# 103532  muscami01      Mike Muscala           ATLANTA_HAWKS     HOME
# 186330  mudiaem01   Emmanuel Mudiay               UTAH_JAZZ     AWAY
# 50178   drumman01    Andre Drummond         DETROIT_PISTONS     HOME
# 55607   humphkr01    Kris Humphries      WASHINGTON_WIZARDS     AWAY
# 111697   hillso01      Solomon Hill    NEW_ORLEANS_PELICANS     HOME
# 185349  hilarne01      Nenê Hilário         HOUSTON_ROCKETS     HOME
# 2032    whiteja02       James White         NEW_YORK_KNICKS     HOME
# 124955  hilarne01      Nenê Hilário         HOUSTON_ROCKETS     HOME
# 165605  forbebr01       Bryn Forbes       SAN_ANTONIO_SPURS     AWAY
# 70427   martike02      Kevin Martin  MINNESOTA_TIMBERWOLVES     AWAY
# 87625   hansbty01  Tyler Hansbrough       CHARLOTTE_HORNETS     HOME
# 45412   ginobma01     Manu Ginóbili       SAN_ANTONIO_SPURS     AWAY
# 85598     linje01        Jeremy Lin       CHARLOTTE_HORNETS     AWAY
#
#                       Opponent Outcome        date game_id1 game_id2 game_id3  \
# 99389      CLEVELAND_CAVALIERS    LOSS  2016-04-11      NaN     5146      NaN
# 46705         DALLAS_MAVERICKS    LOSS  2014-11-03      NaN      NaN     2678
# 1215              PHOENIX_SUNS     WIN  2013-01-08      NaN      NaN      NaN
# 27780           INDIANA_PACERS    LOSS  2013-12-31      NaN     1773      NaN
# 30040             PHOENIX_SUNS    LOSS  2014-01-15     1877      NaN     1886
# 34172             PHOENIX_SUNS     WIN  2014-02-11      NaN      NaN     2085
# 5893           TORONTO_RAPTORS    LOSS  2013-02-08      NaN      NaN      NaN
# 87385            BROOKLYN_NETS     WIN  2016-01-22      NaN      NaN     4590
# 95312       PHILADELPHIA_76ERS     WIN  2016-03-18      NaN     4964     4973
# 44474        MEMPHIS_GRIZZLIES    LOSS  2014-04-29      NaN      NaN      NaN
# 55262            ORLANDO_MAGIC    LOSS  2014-12-27      NaN     3070      NaN
# 150273         TORONTO_RAPTORS    LOSS  2018-03-07      NaN      NaN      NaN
# 56312           BOSTON_CELTICS     WIN  2015-01-03      NaN      NaN      NaN
# 2322         CHARLOTTE_BOBCATS     WIN  2013-01-15      NaN      NaN      562
# 24910     LOS_ANGELES_CLIPPERS     WIN  2013-12-12      NaN      NaN      NaN
# 173342          DENVER_NUGGETS    LOSS  2019-01-25     8598      NaN     8608
# 54474           DENVER_NUGGETS     WIN  2014-12-22      NaN      NaN      NaN
# 131782       SAN_ANTONIO_SPURS     WIN  2017-10-30     6660      NaN      NaN
# 50672           DENVER_NUGGETS    LOSS  2014-11-28      NaN      NaN     2864
# 197248    LOS_ANGELES_CLIPPERS    LOSS  2020-01-05      NaN     9726      NaN
# 95530            BROOKLYN_NETS     WIN  2016-03-19     4972      NaN      NaN
# 6148       CLEVELAND_CAVALIERS     WIN  2013-02-09      NaN      NaN      753
# 200645           ORLANDO_MAGIC     WIN  2020-01-27      NaN      NaN      NaN
# 33422        SAN_ANTONIO_SPURS     WIN  2014-02-06      NaN      NaN      NaN
# 89692            ATLANTA_HAWKS    LOSS  2016-02-05      NaN      NaN     4692
# 4964         MEMPHIS_GRIZZLIES    LOSS  2013-02-01      NaN      NaN      689
# 51282       LOS_ANGELES_LAKERS     WIN  2014-12-03      NaN      NaN      NaN
# 56878         DALLAS_MAVERICKS     WIN  2015-01-07      NaN     3153     3161
# 184721           ORLANDO_MAGIC     WIN  2019-04-21      NaN     9139      NaN
# 36583        MEMPHIS_GRIZZLIES    LOSS  2014-03-03      NaN      NaN      NaN
# 88202         DALLAS_MAVERICKS     WIN  2016-01-27      NaN      NaN      NaN
# 54915      CLEVELAND_CAVALIERS    LOSS  2014-12-26      NaN      NaN      NaN
# 26645          MILWAUKEE_BUCKS     WIN  2013-12-23      NaN      NaN      NaN
# 54272           BOSTON_CELTICS     WIN  2014-12-21     3035      NaN      NaN
# 174858              MIAMI_HEAT    LOSS  2019-02-05      NaN      NaN      NaN
# 93323   MINNESOTA_TIMBERWOLVES    LOSS  2016-03-05      NaN     4863     4869
# 188528        SACRAMENTO_KINGS    LOSS  2019-11-08      NaN      NaN      NaN
# 103532         HOUSTON_ROCKETS     WIN  2016-11-05     5343      NaN      NaN
# 186330      LOS_ANGELES_LAKERS    LOSS  2019-10-25      NaN      NaN     9217
# 50178     LOS_ANGELES_CLIPPERS    LOSS  2014-11-26      NaN     2839      NaN
# 55607         DALLAS_MAVERICKS    LOSS  2014-12-30      NaN     3095     3102
# 111697        DALLAS_MAVERICKS     WIN  2016-12-26      NaN      NaN      NaN
# 185349   GOLDEN_STATE_WARRIORS     WIN  2019-05-06      NaN      NaN      NaN
# 2032       NEW_ORLEANS_HORNETS     WIN  2013-01-13      547      NaN      NaN
# 124955   OKLAHOMA_CITY_THUNDER     WIN  2017-03-26     6347      NaN      NaN
# 165605      LOS_ANGELES_LAKERS    LOSS  2018-12-05      NaN     8234     8244
# 70427   PORTLAND_TRAIL_BLAZERS    LOSS  2015-04-08      NaN     3790     3804
# 87625          NEW_YORK_KNICKS     WIN  2016-01-23      NaN     4588      NaN
# 45412    OKLAHOMA_CITY_THUNDER    LOSS  2014-05-25      NaN      NaN     2621
# 85598           DENVER_NUGGETS    LOSS  2016-01-10      NaN      NaN     4506
#
#        game_id4
# 99389       NaN
# 46705       NaN
# 1215        512
# 27780       NaN
# 30040       NaN
# 34172       NaN
# 5893        735
# 87385       NaN
# 95312       NaN
# 44474      2578
# 55262      3076
# 150273     7534
# 56312      3128
# 2322        NaN
# 24910      1639
# 173342      NaN
# 54474      3041
# 131782      NaN
# 50672       NaN
# 197248      NaN
# 95530       NaN
# 6148        NaN
# 200645     9886
# 33422      2048
# 89692       NaN
# 4964        NaN
# 51282      2896
# 56878       NaN
# 184721      NaN
# 36583      2201
# 88202      4633
# 54915      3065
# 26645      1719
# 54272       NaN
# 174858     8683
# 93323       NaN
# 188528     9311
# 103532      NaN
# 186330      NaN
# 50178      2848
# 55607       NaN
# 111697     5726
# 185349     9167
# 2032        NaN
# 124955      NaN
# 165605      NaN
# 70427       NaN
# 87625      4597
# 45412       NaN
# 85598       NaN
