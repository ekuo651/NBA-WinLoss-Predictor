# %% [markdown]
# # Head to Head Box Scores

# %%
#import py files from different location
import pandas as pd

import sys
sys.path.insert(1, '../Scripts') #path

from schedule_to_slugs import *
from game_match import *

# %%
# encoded_box_scores = pd.read_csv('../Resources/encoded_box_scores.csv')
# schedule_lineup = pd.read_csv('../Resources/schedule_lineup.csv')
# name_all_formats = pd.read_csv('../Resources/name_all_formats.csv')

# %%
encoded_box_scores.head(2)
# Out:
#    Unnamed: 0       slug             name             Team Location  \
# 0           0  anthoca01  Carmelo Anthony  NEW_YORK_KNICKS     HOME
# 1           1  smithjr01       J.R. Smith  NEW_YORK_KNICKS     HOME
#
#                  Opponent Outcome  seconds_played  made_field_goals  \
# 0  PORTLAND_TRAIL_BLAZERS    LOSS          2472.0              14.0
# 1  PORTLAND_TRAIL_BLAZERS    LOSS          2413.0              10.0
#
#    attempted_field_goals  ...  defensive_rebounds  assists  steals  blocks  \
# 0                   24.0  ...                 5.0      4.0     1.0     0.0
# 1                   22.0  ...                 8.0      5.0     3.0     0.0
#
#    turnovers  personal_fouls  game_score       date  game_id  spread
# 0        2.0             3.0        36.5 2013-01-01      459       5
# 1        2.0             2.0        24.0 2013-01-01      459       5
#
# [2 rows x 25 columns]

# %%
todays_games('2015-01-01')
# Out:
# [3115, 3116]

# %%
all_game_ids = list(set(encoded_box_scores.game_id.to_list()))
print(len(all_game_ids))
# Out:
# 9504

# %%
def id_check(game_id):
    if game_id in all_game_ids:
        print('yes')
    else:
        print('no')

# %%
id_check(3865)
# Out:
# yes

# %%
all_game_ids[-1]
# Out:
# 9960

# %%
home_lineup_slugs(todays_games('2015-01-01')[0])
# Out:
# ['butleji01', 'dunlemi02', 'gasolpa01', 'noahjo01', 'rosede01']

# %%
away_lineup_slugs(todays_games('2015-01-01')[0])
# Out:
# ['afflaar01', 'chandwi01', 'farieke01', 'lawsoty01', 'mozgoti01']

# %%
stats_3118 = matchup_per_game_id(3118)

# %%
stats_sample = pd.DataFrame(stats_3118)
stats_sample.head()
# Out:
#              0         1          2         3         4         5         6  \
# 0  1704.000000  5.111111  11.000000  0.888889  2.444444  2.666667  3.888889
# 1  1124.111111  3.888889   6.666667  0.000000  0.111111  1.000000  1.444444
# 2  1542.125000  4.750000   9.500000  1.125000  3.000000  2.375000  3.125000
# 3  1719.000000  1.000000   5.000000  0.000000  0.000000  0.000000  0.000000
# 4  2022.875000  7.375000  13.625000  0.000000  0.000000  1.125000  1.625000
#
#           7         8         9        10        11        12        13  \
# 0  1.000000  4.777778  1.666667  1.000000  0.666667  2.111111  1.777778
# 1  2.222222  3.111111  1.111111  0.555556  0.888889  1.222222  3.333333
# 2  0.250000  3.500000  3.625000  1.625000  0.625000  3.000000  2.125000
# 3  0.000000  0.000000  6.000000  2.000000  0.000000  5.000000  2.000000
# 4  3.750000  7.625000  1.375000  1.000000  0.875000  1.875000  2.875000
#
#           14
# 0   9.577778
# 1   7.377778
# 2   9.925000
# 3  -0.700000
# ...

# %%
head_to_head1 = pd.DataFrame()
# game 4143 added
# game 4144 added
# game 4145 added
# game 4146 added
# game 4147 added
# game 4148 added
# game 4149 added
# game 4150 added
# game 4151 added
# game 4152 added
# game 4153 added
# game 4154 added
# game 4155 added
# game 4156 added
# ...

# %%
head_to_head2 = pd.DataFrame()
for i in range(4972,9961):
    temp = matchup_per_game_id(i)
    head_to_head2 = head_to_head2.append(temp)
    print(f'game {i} added')
# Out:
# game 4972 added
# game 4973 added
# game 4974 added
# game 4975 added
# game 4976 added
# game 4977 added
# game 4978 added
# game 4979 added
# game 4980 added
# game 4981 added
# game 4982 added
# game 4983 added
# game 4984 added
# game 4985 added
# game 4986 added
# game 4987 added
# game 4988 added
# game 4989 added
# game 4990 added
# game 4991 added
# game 4992 added
# game 4993 added
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-66-119d213dd93a> in <module>
#       1 head_to_head2 = pd.DataFrame()
#       2 for i in range(4972,9961):
# ----> 3     temp = matchup_per_game_id(i)
#       4     head_to_head2 = head_to_head2.append(temp)
#       5     print(f'game {i} added')
#
# ~\Project-3\Scripts\game_match.py in matchup_per_game_id(game_id)
#      54
#      55 def matchup_per_game_id(game_id):
# ...

# %%
head_to_head_1 = pd.DataFrame()
for i in range(9215,9913):
    temp = matchup_per_game_id(i)
    head_to_head_1 = head_to_head_1.append(temp)
    print(f'game {i} added')
# Out:
# game 9215 added
# game 9216 added
# game 9217 added
# game 9218 added
# game 9219 added
# game 9220 added
# game 9221 added
# game 9222 added
# game 9223 added
# game 9224 added
# game 9225 added
# game 9226 added
# game 9227 added
# game 9228 added
# game 9229 added
# game 9230 added
# game 9231 added
# game 9232 added
# game 9233 added
# game 9234 added
# game 9235 added
# game 9236 added
# game 9237 added
# game 9238 added
# game 9239 added
# game 9240 added
# game 9241 added
# game 9242 added
# game 9243 added
# game 9244 added
# game 9245 added
# game 9246 added
# game 9247 added
# game 9248 added
# game 9249 added
# game 9250 added
# game 9251 added
# game 9252 added
# game 9253 added
# game 9254 added
# game 9255 added
# game 9256 added
# game 9257 added
# game 9258 added
# game 9259 added
# game 9260 added
# game 9261 added
# game 9262 added
# game 9263 added
# game 9264 added
# game 9265 added
# game 9266 added
# game 9267 added
# game 9268 added
# game 9269 added
# ...

# %%
head_to_head_1.describe()
# Out:
#                 0            1            2            3            4   \
# count  3287.000000  3287.000000  3287.000000  3287.000000  3287.000000
# mean   1625.867013     4.904553    10.598309     1.259518     3.525071
# std     418.376690     2.373381     4.848321     0.975154     2.378732
# min      11.000000     0.000000     0.000000     0.000000     0.000000
# 25%    1362.027193     3.102632     6.800000     0.470833     1.666667
# 50%    1700.500000     4.684211    10.111111     1.166667     3.416667
# 75%    1948.840226     6.333333    13.833333     1.909091     5.181818
# max    2908.500000    15.500000    28.500000     7.500000    14.571429
#
#                 5            6            7            8            9   ...  \
# count  3287.000000  3287.000000  3287.000000  3287.000000  3287.000000  ...
# mean      2.247437     2.908182     1.172236     4.018145     2.850931  ...
# std       1.762586     2.156317     0.989115     2.139225     2.185548  ...
# ...

# %%
head_to_head_1.to_csv('../Resources/box_scores_oct25_jan31.csv')
